# %%
from database import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-c019b2ad7344> in <module>()
# ----> 1 from database import *
#
# D:\Python\car_loan_project\database.py in <module>()
# ----> 1 import psycopg2
#       2 import getpass
#       3 import pandas as pd
#       4 from configparser import ConfigParser
#       5
#
# ModuleNotFoundError: No module named 'psycopg2'

# %%
from platform import python_version
print(python_version())
# Out:
# 3.6.3

# %%
# !jupyter update
# Out:
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# optional arguments:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: bundlerextension console kernel kernelspec lab
# labextension migrate nbconvert nbextension notebook qtconsole run
# serverextension theme troubleshoot trust
#
# Jupyter command `jupyter-update` not found.

# %%
# !conda install psycopg2
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
# !pip freeze
# Out:
# absl-py==0.8.1
# alembic==1.5.8
# altgraph==0.15
# aniso8601==8.0.0
# anyio==3.6.1
# anytree==2.4.3
# argon2-cffi==20.1.0
# asn1crypto==0.24.0
# astor==0.6.2
# astunparse==1.6.3
# async-generator==1.10
# attrs==20.3.0
# Automat==0.6.0
# Babel==2.10.1
# backcall==0.1.0
# Beaker==1.9.1
# beautifulsoup4==4.6.0
# binarytree==5.1.0
# bleach==1.5.0
# boto==2.49.0
# boto3==1.10.28
# botocore==1.13.28
# bottle==0.12.19
# bs4==0.0.1
# cachetools==4.1.0
# certifi==2018.1.18
# cffi==1.14.4
# chardet==3.0.4
# class-resolver==0.0.12
# click==7.1.2
# click-default-group==1.2.2
# cliff==3.7.0
# clipboard==0.0.4
# cmaes==0.8.2
# cmd2==1.5.0
# colorama==0.3.9
# colorlog==5.0.1
# constantly==15.1.0
# CProfileV==1.0.7
# cryptography==37.0.2
# cssselect==1.0.3
# cycler==0.10.0
# cymem==2.0.6
# dataclasses-json==0.5.2
# decorator==4.3.0
# defusedxml==0.6.0
# docdata==0.0.3
# docutils==0.15.2
# entrypoints==0.2.3
# et-xmlfile==1.0.1
# fastapi==0.78.0
# fastjsonschema==2.15.3
# Flask==1.1.2
# ...
